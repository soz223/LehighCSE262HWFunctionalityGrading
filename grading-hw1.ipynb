# %%
import os

# %%
with open('participants.txt') as f:
    # peoples = f.readlines().remove('\n')
    peoples = f.read().splitlines()

# Loop through each email and extract the username part (before '@lehigh.edu')
for people in peoples:
    
    # Construct the GitLab repo URL using the email username
    repo_url = f"http://gitlab.cse.lehigh.edu/{people}-cse262/homework-1"
    
    # Call the Python script to check the repo
    # You would use os.system() or subprocess to execute the shell command

    # if exception occurs, print the error message
    error = os.system(f"python check_repo.py {repo_url}")
    if error:
        print(f"Repo for {people} is not good!")
        print(error)
        continue
    else:
        # print(f"Repo for {people} is good!")
        print(error)
# Out:
# Successfully authenticated with GitLab.
# Accessed project: Quiz 1
# Available branches:
#   - main
#
# Default branch detected: main
#
# Contents of the repository 'Quiz 1':
#   📄 README.md
# Failed to retrieve the file 'tests/lex.rs'. Make sure it exists.
#
# Number of tests in 'tests/lex.rs': 0
# No CI/CD pipelines found for branch 'main'.
# Total number of commits on branch 'main': 16
#
# Commit Details for branch 'main':
# Commit ID: a9cb9590dfb9bf1783b31fbd5b92eb8414e1f1b5
# Author: Agnew, Alex <ala226@lehigh.edu>
# Date: 2024-09-10T03:21:24.000+00:00
# Message: Replace README.md
# ----------------------------------------
# Commit ID: 969a4ed8d50a090a2e6b20ba7794ce4d63e389cf
# Author: Agnew, Alex <ala226@lehigh.edu>
# Date: 2024-09-10T03:21:12.000+00:00
# Message: Replace README.md
# ----------------------------------------
# Commit ID: ad5c5bce84e05932968d151f2134d9b8dd53d526
# Author: Agnew, Alex <ala226@lehigh.edu>
# Date: 2024-09-10T03:21:01.000+00:00
# Message: Replace README.md
# ----------------------------------------
# Commit ID: 41afd6e7127831ac79285f8fd14f9d50183d33bb
# Author: Agnew, Alex <ala226@lehigh.edu>
# Date: 2024-09-10T03:20:49.000+00:00
# Message: Replace README.md
# ----------------------------------------
# Commit ID: 4e1324dca5c318d47723c6ecd2a1f047d8aad214
# Author: Agnew, Alex <ala226@lehigh.edu>
# Date: 2024-09-10T03:20:38.000+00:00
# Message: Replace README.md
# ----------------------------------------
# Commit ID: cc6edf07af344ae053b5778e2216a735356afef9
# Author: Agnew, Alex <ala226@lehigh.edu>
# Date: 2024-09-10T03:19:53.000+00:00
# Message: Replace README.md
# ----------------------------------------
# Commit ID: 49c1136e79ec887b17d1ca8a468619c358e6653a
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:14:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: a60933a085c31dce3488d0f2c5badbc480017b08
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:47.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: c6b5d4c95af2b5f51090f6bf8f8bd60ed59f5428
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:04.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: e8d19a850098ce2d0eb486c38ee7b79c1b93eb2e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:12:30.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b637fa4f0606d08296b456eae9faf504e2465b3f
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:53.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 36751af0d496b12a77832b8d5218c538314de147
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:26.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b6e5cb3df02e086cb2f978e883188da754033c68
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-06T16:18:43.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 62b1ed122e385497e7ce37de7a03e0d626a00e76
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-05T14:16:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 3e4cd7d66509feda1cfbb998e2de0499696fd0b0
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:30:56.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: ac07498750689ea3e4ef31be6cb84eb62e5d494e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:22:36.000+00:00
# Message: Initial commit
# ----------------------------------------
#
# Commits per author on branch 'main':
# Agnew, Alex: 6 commit(s)
# Corey Montella: 10 commit(s)
#
# Commit frequency on branch 'main':
# 2023-02-09: 2 commit(s)
# 2023-09-05: 1 commit(s)
# 2023-09-06: 1 commit(s)
# 2024-01-31: 2 commit(s)
# 2024-09-04: 4 commit(s)
# 2024-09-10: 6 commit(s)
#
# All required files are present.
#
# No merge requests found.
#
# No CI/CD pipelines found for branch 'main'.
# 0
# Successfully authenticated with GitLab.
# Accessed project: Quiz 1
# Available branches:
#   - main
#
# Default branch detected: main
#
# Contents of the repository 'Quiz 1':
#   📄 README.md
# Failed to retrieve the file 'tests/lex.rs'. Make sure it exists.
#
# Number of tests in 'tests/lex.rs': 0
# No CI/CD pipelines found for branch 'main'.
# Total number of commits on branch 'main': 16
#
# Commit Details for branch 'main':
# Commit ID: 073ced0e96847bc9edb633d6fa71680096d385e0
# Author: Shirley Angos <shirleyangos@ShirleyMac-5.local>
# Date: 2024-09-09T23:53:54.000-04:00
# Message: question 6
#
# ----------------------------------------
# Commit ID: 92ae85fa536d00cd30c2fd07b294d125c9a458c1
# Author: Shirley Angos <shirleyangos@ShirleyMac-5.local>
# Date: 2024-09-09T23:50:36.000-04:00
# Message: question 5
#
# ----------------------------------------
# Commit ID: 9822c9e97b99bd416b48c7d03c54bda3af29a169
# Author: Shirley Angos <shirleyangos@ShirleyMac-5.local>
# Date: 2024-09-09T23:48:36.000-04:00
# Message: Adding onto question 4
#
# ----------------------------------------
# Commit ID: 969cf686b440285e2c311ab71263c441298bf9f3
# Author: Shirley Angos <shirleyangos@ShirleyMac-5.local>
# Date: 2024-09-09T23:46:15.000-04:00
# Message: Question 4
#
# ----------------------------------------
# Commit ID: 2c6c58db938bc3640a1d2b63375f382232c7726e
# Author: Shirley Angos <shirleyangos@ShirleyMac-5.local>
# Date: 2024-09-09T23:43:32.000-04:00
# Message:  question 3
#
# ----------------------------------------
# Commit ID: 05fca1bd7be2ea2f791a05b09929e65e130c99ad
# Author: Shirley Angos <shirleyangos@ShirleyMac-5.local>
# Date: 2024-09-09T23:15:23.000-04:00
# Message: Question 1
#
# ----------------------------------------
# Commit ID: 49c1136e79ec887b17d1ca8a468619c358e6653a
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:14:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: a60933a085c31dce3488d0f2c5badbc480017b08
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:47.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: c6b5d4c95af2b5f51090f6bf8f8bd60ed59f5428
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:04.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: e8d19a850098ce2d0eb486c38ee7b79c1b93eb2e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:12:30.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b637fa4f0606d08296b456eae9faf504e2465b3f
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:53.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 36751af0d496b12a77832b8d5218c538314de147
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:26.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b6e5cb3df02e086cb2f978e883188da754033c68
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-06T16:18:43.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 62b1ed122e385497e7ce37de7a03e0d626a00e76
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-05T14:16:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 3e4cd7d66509feda1cfbb998e2de0499696fd0b0
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:30:56.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: ac07498750689ea3e4ef31be6cb84eb62e5d494e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:22:36.000+00:00
# Message: Initial commit
# ----------------------------------------
#
# Commits per author on branch 'main':
# Shirley Angos: 6 commit(s)
# Corey Montella: 10 commit(s)
#
# Commit frequency on branch 'main':
# 2023-02-09: 2 commit(s)
# 2023-09-05: 1 commit(s)
# 2023-09-06: 1 commit(s)
# 2024-01-31: 2 commit(s)
# 2024-09-04: 4 commit(s)
# 2024-09-09: 6 commit(s)
#
# All required files are present.
#
# No merge requests found.
#
# No CI/CD pipelines found for branch 'main'.
# 0
# Successfully authenticated with GitLab.
# Accessed project: Quiz 1
# Available branches:
#   - main
#
# Default branch detected: main
#
# Contents of the repository 'Quiz 1':
#   📄 README.md
# Failed to retrieve the file 'tests/lex.rs'. Make sure it exists.
#
# Number of tests in 'tests/lex.rs': 0
# No CI/CD pipelines found for branch 'main'.
# Total number of commits on branch 'main': 17
#
# Commit Details for branch 'main':
# Commit ID: 2c5455ae8c7ad6afa891bd00e240f6683b1dce1a
# Author: Rusanka <rvb226@lehigh.edu>
# Date: 2024-09-09T21:32:07.000-04:00
# Message: wrapped up the quiz
#
# ----------------------------------------
# Commit ID: cba6207a09a7249deedbd2cc3f319de4e324bba4
# Author: Rusanka <rvb226@lehigh.edu>
# Date: 2024-09-09T21:13:54.000-04:00
# Message: answered q6
#
# ----------------------------------------
# Commit ID: 049590ec2ed3c49c0064a54d842e94a7396d7f6a
# Author: Rusanka <rvb226@lehigh.edu>
# Date: 2024-09-09T21:08:01.000-04:00
# Message: answered q5
#
# ----------------------------------------
# Commit ID: 8c86a62e64b9f9b0f2162713095ee5a788fc0a65
# Author: Rusanka <rvb226@lehigh.edu>
# Date: 2024-09-09T14:43:44.000-04:00
# Message: answered q4
#
# ----------------------------------------
# Commit ID: 0a31d6a1ee296017b7680387090f0da723af58aa
# Author: Rusanka <rvb226@lehigh.edu>
# Date: 2024-09-09T14:35:55.000-04:00
# Message: answered q3
#
# ----------------------------------------
# Commit ID: cd95b33f56a4154326cd26eeac3ff12488829b97
# Author: Rusanka <rvb226@lehigh.edu>
# Date: 2024-09-09T14:10:52.000-04:00
# Message: answered q2
#
# ----------------------------------------
# Commit ID: 0818a6740a409866b0c4ae775a95cbf7de1211f7
# Author: Rusanka <rvb226@lehigh.edu>
# Date: 2024-09-09T14:04:46.000-04:00
# Message: answered q1
#
# ----------------------------------------
# Commit ID: 49c1136e79ec887b17d1ca8a468619c358e6653a
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:14:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: a60933a085c31dce3488d0f2c5badbc480017b08
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:47.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: c6b5d4c95af2b5f51090f6bf8f8bd60ed59f5428
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:04.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: e8d19a850098ce2d0eb486c38ee7b79c1b93eb2e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:12:30.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b637fa4f0606d08296b456eae9faf504e2465b3f
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:53.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 36751af0d496b12a77832b8d5218c538314de147
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:26.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b6e5cb3df02e086cb2f978e883188da754033c68
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-06T16:18:43.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 62b1ed122e385497e7ce37de7a03e0d626a00e76
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-05T14:16:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 3e4cd7d66509feda1cfbb998e2de0499696fd0b0
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:30:56.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: ac07498750689ea3e4ef31be6cb84eb62e5d494e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:22:36.000+00:00
# Message: Initial commit
# ----------------------------------------
#
# Commits per author on branch 'main':
# Rusanka: 7 commit(s)
# Corey Montella: 10 commit(s)
#
# Commit frequency on branch 'main':
# 2023-02-09: 2 commit(s)
# 2023-09-05: 1 commit(s)
# 2023-09-06: 1 commit(s)
# 2024-01-31: 2 commit(s)
# 2024-09-04: 4 commit(s)
# 2024-09-09: 7 commit(s)
#
# All required files are present.
#
# No merge requests found.
#
# No CI/CD pipelines found for branch 'main'.
# 0
# Successfully authenticated with GitLab.
# Accessed project: Quiz 1
# Available branches:
#   - main
#
# Default branch detected: main
#
# Contents of the repository 'Quiz 1':
#   📄 README.md
# Failed to retrieve the file 'tests/lex.rs'. Make sure it exists.
#
# Number of tests in 'tests/lex.rs': 0
# No CI/CD pipelines found for branch 'main'.
# Total number of commits on branch 'main': 14
#
# Commit Details for branch 'main':
# Commit ID: b88b13c6dddf07b5c0eaadd01e654376883bf163
# Author: Benincasa, Chris J. <cjb325@lehigh.edu>
# Date: 2024-09-11T04:39:57.000+00:00
# Message: Update file README.md
# ----------------------------------------
# Commit ID: 2a5b628c340c2cdb9d34b51303d60be63913816b
# Author: Benincasa, Chris J. <cjb325@lehigh.edu>
# Date: 2024-09-10T00:31:11.000+00:00
# Message: Update file README.md
# ----------------------------------------
# Commit ID: ed4db29d2710f868b37a171e609fb96fb8e7b93b
# Author: Benincasa, Chris J. <cjb325@lehigh.edu>
# Date: 2024-09-10T00:22:31.000+00:00
# Message: Update file README.md
# ----------------------------------------
# Commit ID: 19d05f741be5a1ccf55605ac488b800358f2359d
# Author: Benincasa, Chris J. <cjb325@lehigh.edu>
# Date: 2024-09-10T00:14:26.000+00:00
# Message: Update file README.md
# ----------------------------------------
# Commit ID: 49c1136e79ec887b17d1ca8a468619c358e6653a
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:14:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: a60933a085c31dce3488d0f2c5badbc480017b08
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:47.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: c6b5d4c95af2b5f51090f6bf8f8bd60ed59f5428
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:04.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: e8d19a850098ce2d0eb486c38ee7b79c1b93eb2e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:12:30.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b637fa4f0606d08296b456eae9faf504e2465b3f
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:53.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 36751af0d496b12a77832b8d5218c538314de147
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:26.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b6e5cb3df02e086cb2f978e883188da754033c68
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-06T16:18:43.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 62b1ed122e385497e7ce37de7a03e0d626a00e76
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-05T14:16:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 3e4cd7d66509feda1cfbb998e2de0499696fd0b0
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:30:56.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: ac07498750689ea3e4ef31be6cb84eb62e5d494e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:22:36.000+00:00
# Message: Initial commit
# ----------------------------------------
#
# Commits per author on branch 'main':
# Benincasa, Chris J.: 4 commit(s)
# Corey Montella: 10 commit(s)
#
# Commit frequency on branch 'main':
# 2023-02-09: 2 commit(s)
# 2023-09-05: 1 commit(s)
# 2023-09-06: 1 commit(s)
# 2024-01-31: 2 commit(s)
# 2024-09-04: 4 commit(s)
# 2024-09-10: 3 commit(s)
# 2024-09-11: 1 commit(s)
#
# All required files are present.
#
# No merge requests found.
#
# No CI/CD pipelines found for branch 'main'.
# 0
# Successfully authenticated with GitLab.
# Accessed project: Quiz 1
# Available branches:
#   - main
#
# Default branch detected: main
#
# Contents of the repository 'Quiz 1':
#   📄 README.md
# Failed to retrieve the file 'tests/lex.rs'. Make sure it exists.
#
# Number of tests in 'tests/lex.rs': 0
# No CI/CD pipelines found for branch 'main'.
# Total number of commits on branch 'main': 16
#
# Commit Details for branch 'main':
# Commit ID: 1e0c4741a8b6ee9c7ca830bc2dd87b89663c3b35
# Author: Cecy Benitez <ccb226@lehigh.edu>
# Date: 2024-09-08T19:56:26.000-04:00
# Message: Question 6
#
# ----------------------------------------
# Commit ID: 78ef9a2c139b93c303e8c73a9407dfcdce58c136
# Author: Cecy Benitez <ccb226@lehigh.edu>
# Date: 2024-09-08T19:45:55.000-04:00
# Message: Question 5
#
# ----------------------------------------
# Commit ID: c6cab563aea0e8b620aed7dff59ea5f78f22c6cc
# Author: Cecy Benitez <ccb226@lehigh.edu>
# Date: 2024-09-08T19:40:13.000-04:00
# Message: Question 4
#
# ----------------------------------------
# Commit ID: 8038b6ff0ecba42e31e26956388d23a8dda5eae9
# Author: Cecy Benitez <ccb226@lehigh.edu>
# Date: 2024-09-08T18:56:43.000-04:00
# Message: Question 3
#
# ----------------------------------------
# Commit ID: 07e2f978eacfe868d7a7038527ab28d95090e7d4
# Author: Cecy Benitez <ccb226@lehigh.edu>
# Date: 2024-09-08T18:51:52.000-04:00
# Message: Question 2
#
# ----------------------------------------
# Commit ID: 2152e32fe3447f06c90790050a5190f51072085c
# Author: Cecy Benitez <ccb226@lehigh.edu>
# Date: 2024-09-08T18:42:39.000-04:00
# Message: Question 1
#
# ----------------------------------------
# Commit ID: 49c1136e79ec887b17d1ca8a468619c358e6653a
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:14:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: a60933a085c31dce3488d0f2c5badbc480017b08
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:47.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: c6b5d4c95af2b5f51090f6bf8f8bd60ed59f5428
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:04.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: e8d19a850098ce2d0eb486c38ee7b79c1b93eb2e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:12:30.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b637fa4f0606d08296b456eae9faf504e2465b3f
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:53.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 36751af0d496b12a77832b8d5218c538314de147
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:26.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b6e5cb3df02e086cb2f978e883188da754033c68
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-06T16:18:43.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 62b1ed122e385497e7ce37de7a03e0d626a00e76
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-05T14:16:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 3e4cd7d66509feda1cfbb998e2de0499696fd0b0
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:30:56.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: ac07498750689ea3e4ef31be6cb84eb62e5d494e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:22:36.000+00:00
# Message: Initial commit
# ----------------------------------------
#
# Commits per author on branch 'main':
# Cecy Benitez: 6 commit(s)
# Corey Montella: 10 commit(s)
#
# Commit frequency on branch 'main':
# 2023-02-09: 2 commit(s)
# 2023-09-05: 1 commit(s)
# 2023-09-06: 1 commit(s)
# 2024-01-31: 2 commit(s)
# 2024-09-04: 4 commit(s)
# 2024-09-08: 6 commit(s)
#
# All required files are present.
#
# No merge requests found.
#
# No CI/CD pipelines found for branch 'main'.
# 0
# Successfully authenticated with GitLab.
# Accessed project: Quiz 1
# Available branches:
#   - main
#
# Default branch detected: main
#
# Contents of the repository 'Quiz 1':
#   📄 README.md
# Failed to retrieve the file 'tests/lex.rs'. Make sure it exists.
#
# Number of tests in 'tests/lex.rs': 0
# No CI/CD pipelines found for branch 'main'.
# Total number of commits on branch 'main': 16
#
# Commit Details for branch 'main':
# Commit ID: d055fe847069d1701b2057993f2fafaeaa3e7c3f
# Author: Josh Berdon <job426@lehigh.edu>
# Date: 2024-09-07T20:07:39.000-04:00
# Message: q6
#
# ----------------------------------------
# Commit ID: fa3b14ef24d154615d87356e979eb20637dbf485
# Author: Josh Berdon <job426@lehigh.edu>
# Date: 2024-09-07T20:02:57.000-04:00
# Message: q5
#
# ----------------------------------------
# Commit ID: 454a807c24ff21ea29ed9747a004cf736e0d0983
# Author: Josh Berdon <job426@lehigh.edu>
# Date: 2024-09-07T19:59:58.000-04:00
# Message: q4
#
# ----------------------------------------
# Commit ID: dd8911e0c96a640ce3deb50f613b8e7976936a27
# Author: Josh Berdon <job426@lehigh.edu>
# Date: 2024-09-07T19:43:00.000-04:00
# Message: q3
#
# ----------------------------------------
# Commit ID: e21dcc8a547c44321284a1169ea843b7514f146c
# Author: Josh Berdon <job426@lehigh.edu>
# Date: 2024-09-07T19:15:59.000-04:00
# Message: q2
#
# ----------------------------------------
# Commit ID: 03a92ae97efd78063ed71f09fbf30db4184398a9
# Author: Josh Berdon <job426@lehigh.edu>
# Date: 2024-09-07T19:06:41.000-04:00
# Message: q1
#
# ----------------------------------------
# Commit ID: 49c1136e79ec887b17d1ca8a468619c358e6653a
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:14:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: a60933a085c31dce3488d0f2c5badbc480017b08
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:47.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: c6b5d4c95af2b5f51090f6bf8f8bd60ed59f5428
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:04.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: e8d19a850098ce2d0eb486c38ee7b79c1b93eb2e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:12:30.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b637fa4f0606d08296b456eae9faf504e2465b3f
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:53.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 36751af0d496b12a77832b8d5218c538314de147
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:26.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b6e5cb3df02e086cb2f978e883188da754033c68
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-06T16:18:43.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 62b1ed122e385497e7ce37de7a03e0d626a00e76
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-05T14:16:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 3e4cd7d66509feda1cfbb998e2de0499696fd0b0
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:30:56.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: ac07498750689ea3e4ef31be6cb84eb62e5d494e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:22:36.000+00:00
# Message: Initial commit
# ----------------------------------------
#
# Commits per author on branch 'main':
# Josh Berdon: 6 commit(s)
# Corey Montella: 10 commit(s)
#
# Commit frequency on branch 'main':
# 2023-02-09: 2 commit(s)
# 2023-09-05: 1 commit(s)
# 2023-09-06: 1 commit(s)
# 2024-01-31: 2 commit(s)
# 2024-09-04: 4 commit(s)
# 2024-09-07: 6 commit(s)
#
# All required files are present.
#
# No merge requests found.
#
# No CI/CD pipelines found for branch 'main'.
# 0
# Successfully authenticated with GitLab.
# Accessed project: Quiz 1
# Available branches:
#   - main
#
# Default branch detected: main
#
# Contents of the repository 'Quiz 1':
#   📄 README.md
# Failed to retrieve the file 'tests/lex.rs'. Make sure it exists.
#
# Number of tests in 'tests/lex.rs': 0
# No CI/CD pipelines found for branch 'main'.
# Total number of commits on branch 'main': 13
#
# Commit Details for branch 'main':
# Commit ID: 60bf6551c0b121ad27a7ac9d7bc854a18ff2902d
# Author: Boffi, Juan B. <jbb225@lehigh.edu>
# Date: 2024-09-10T02:40:18.000+00:00
# Message: Finishedddd
# ----------------------------------------
# Commit ID: 0d134fa4d3216d6134378d263d123a36b07c4018
# Author: Boffi, Juan B. <jbb225@lehigh.edu>
# Date: 2024-09-10T02:39:21.000+00:00
# Message: Update file README.md
# ----------------------------------------
# Commit ID: c9f721b157f88ebf6aefe42a76f47aeaff8ee6c9
# Author: Boffi, Juan B. <jbb225@lehigh.edu>
# Date: 2024-09-09T15:31:09.000+00:00
# Message: Forgot to do this for the first two, but here is the first commit asnwering 1-3
# ----------------------------------------
# Commit ID: 49c1136e79ec887b17d1ca8a468619c358e6653a
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:14:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: a60933a085c31dce3488d0f2c5badbc480017b08
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:47.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: c6b5d4c95af2b5f51090f6bf8f8bd60ed59f5428
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:04.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: e8d19a850098ce2d0eb486c38ee7b79c1b93eb2e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:12:30.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b637fa4f0606d08296b456eae9faf504e2465b3f
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:53.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 36751af0d496b12a77832b8d5218c538314de147
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:26.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b6e5cb3df02e086cb2f978e883188da754033c68
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-06T16:18:43.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 62b1ed122e385497e7ce37de7a03e0d626a00e76
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-05T14:16:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 3e4cd7d66509feda1cfbb998e2de0499696fd0b0
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:30:56.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: ac07498750689ea3e4ef31be6cb84eb62e5d494e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:22:36.000+00:00
# Message: Initial commit
# ----------------------------------------
#
# Commits per author on branch 'main':
# Boffi, Juan B.: 3 commit(s)
# Corey Montella: 10 commit(s)
#
# Commit frequency on branch 'main':
# 2023-02-09: 2 commit(s)
# 2023-09-05: 1 commit(s)
# 2023-09-06: 1 commit(s)
# 2024-01-31: 2 commit(s)
# 2024-09-04: 4 commit(s)
# 2024-09-09: 1 commit(s)
# 2024-09-10: 2 commit(s)
#
# All required files are present.
#
# No merge requests found.
#
# No CI/CD pipelines found for branch 'main'.
# 0
# Successfully authenticated with GitLab.
# Accessed project: Quiz 1
# Available branches:
#   - main
#
# Default branch detected: main
#
# Contents of the repository 'Quiz 1':
#   📄 README.md
# Failed to retrieve the file 'tests/lex.rs'. Make sure it exists.
#
# Number of tests in 'tests/lex.rs': 0
# No CI/CD pipelines found for branch 'main'.
# Total number of commits on branch 'main': 17
#
# Commit Details for branch 'main':
# Commit ID: 98349cd94f9df8f26bdf50b34a704a31c65843ad
# Author: Brianna Burchett <beb727@lehigh.edu>
# Date: 2024-09-09T11:21:46.000-04:00
# Message: question5
#
# ----------------------------------------
# Commit ID: 92e945afc7e09ebe93ef216f901f5986b35715bb
# Author: Brianna Burchett <beb727@lehigh.edu>
# Date: 2024-09-09T11:20:25.000-04:00
# Message: question6
#
# ----------------------------------------
# Commit ID: b4ab0875a79a5ed11b9169b7485bbb4e17abe0e9
# Author: Brianna Burchett <beb727@lehigh.edu>
# Date: 2024-09-09T11:17:59.000-04:00
# Message: question4
#
# ----------------------------------------
# Commit ID: 1cbbf646387647a9e6e416c7f325572fda3cd4e1
# Author: Brianna Burchett <beb727@lehigh.edu>
# Date: 2024-09-09T11:12:37.000-04:00
# Message: question4
#
# ----------------------------------------
# Commit ID: fa97c689528ab77b76a39e4fb1174c018c629a35
# Author: Brianna Burchett <beb727@lehigh.edu>
# Date: 2024-09-09T11:10:34.000-04:00
# Message: question3
#
# ----------------------------------------
# Commit ID: d9c4b25da709f0dd7937f31e24e9f4e7738dace3
# Author: Brianna Burchett <beb727@lehigh.edu>
# Date: 2024-09-09T10:49:46.000-04:00
# Message: question2
#
# ----------------------------------------
# Commit ID: 83085b0ce73e1ed97b3415b7f004565f16d673f2
# Author: Brianna Burchett <beb727@lehigh.edu>
# Date: 2024-09-09T10:39:31.000-04:00
# Message: question1
#
# ----------------------------------------
# Commit ID: 49c1136e79ec887b17d1ca8a468619c358e6653a
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:14:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: a60933a085c31dce3488d0f2c5badbc480017b08
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:47.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: c6b5d4c95af2b5f51090f6bf8f8bd60ed59f5428
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:04.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: e8d19a850098ce2d0eb486c38ee7b79c1b93eb2e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:12:30.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b637fa4f0606d08296b456eae9faf504e2465b3f
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:53.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 36751af0d496b12a77832b8d5218c538314de147
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:26.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b6e5cb3df02e086cb2f978e883188da754033c68
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-06T16:18:43.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 62b1ed122e385497e7ce37de7a03e0d626a00e76
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-05T14:16:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 3e4cd7d66509feda1cfbb998e2de0499696fd0b0
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:30:56.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: ac07498750689ea3e4ef31be6cb84eb62e5d494e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:22:36.000+00:00
# Message: Initial commit
# ----------------------------------------
#
# Commits per author on branch 'main':
# Brianna Burchett: 7 commit(s)
# Corey Montella: 10 commit(s)
#
# Commit frequency on branch 'main':
# 2023-02-09: 2 commit(s)
# 2023-09-05: 1 commit(s)
# 2023-09-06: 1 commit(s)
# 2024-01-31: 2 commit(s)
# 2024-09-04: 4 commit(s)
# 2024-09-09: 7 commit(s)
#
# All required files are present.
#
# No merge requests found.
#
# No CI/CD pipelines found for branch 'main'.
# 0
# Successfully authenticated with GitLab.
# Failed to retrieve the project. Please check the repository URL.
# Repo for gcb325 is not good!
# 256
# Successfully authenticated with GitLab.
# Accessed project: Quiz 1
# Available branches:
#   - main
#
# Default branch detected: main
#
# Contents of the repository 'Quiz 1':
#   📄 README.md
# Failed to retrieve the file 'tests/lex.rs'. Make sure it exists.
#
# Number of tests in 'tests/lex.rs': 0
# No CI/CD pipelines found for branch 'main'.
# Total number of commits on branch 'main': 14
#
# Commit Details for branch 'main':
# Commit ID: 58a426cdc0e69fe0f817f67cdde7f0f16f910a76
# Author: Kevin Cawood <kbc225@lehigh.edu>
# Date: 2024-09-04T18:56:27.000-04:00
# Message: question 4
#
# ----------------------------------------
# Commit ID: 459b780102054e1f4e98fa3109d3a37f5cf22ef6
# Author: Kevin Cawood <kbc225@lehigh.edu>
# Date: 2024-09-04T18:52:32.000-04:00
# Message: question 3 complete
#
# ----------------------------------------
# Commit ID: df88660e1af63c695a70f36042c65308904ec749
# Author: Kevin Cawood <kbc225@lehigh.edu>
# Date: 2024-09-04T18:33:43.000-04:00
# Message: question 2 complete
#
# ----------------------------------------
# Commit ID: 6c196bffe7c3c5776623ae99e7390765065b3491
# Author: Kevin Cawood <kbc225@lehigh.edu>
# Date: 2024-09-04T18:33:25.000-04:00
# Message: question 1 complete
#
# ----------------------------------------
# Commit ID: 49c1136e79ec887b17d1ca8a468619c358e6653a
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:14:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: a60933a085c31dce3488d0f2c5badbc480017b08
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:47.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: c6b5d4c95af2b5f51090f6bf8f8bd60ed59f5428
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:04.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: e8d19a850098ce2d0eb486c38ee7b79c1b93eb2e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:12:30.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b637fa4f0606d08296b456eae9faf504e2465b3f
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:53.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 36751af0d496b12a77832b8d5218c538314de147
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:26.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b6e5cb3df02e086cb2f978e883188da754033c68
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-06T16:18:43.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 62b1ed122e385497e7ce37de7a03e0d626a00e76
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-05T14:16:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 3e4cd7d66509feda1cfbb998e2de0499696fd0b0
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:30:56.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: ac07498750689ea3e4ef31be6cb84eb62e5d494e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:22:36.000+00:00
# Message: Initial commit
# ----------------------------------------
#
# Commits per author on branch 'main':
# Kevin Cawood: 4 commit(s)
# Corey Montella: 10 commit(s)
#
# Commit frequency on branch 'main':
# 2023-02-09: 2 commit(s)
# 2023-09-05: 1 commit(s)
# 2023-09-06: 1 commit(s)
# 2024-01-31: 2 commit(s)
# 2024-09-04: 8 commit(s)
#
# All required files are present.
#
# No merge requests found.
#
# No CI/CD pipelines found for branch 'main'.
# 0
# Successfully authenticated with GitLab.
# Accessed project: Quiz 1
# Available branches:
#   - main
#
# Default branch detected: main
#
# Contents of the repository 'Quiz 1':
#   📄 README.md
# Failed to retrieve the file 'tests/lex.rs'. Make sure it exists.
#
# Number of tests in 'tests/lex.rs': 0
# No CI/CD pipelines found for branch 'main'.
# Total number of commits on branch 'main': 16
#
# Commit Details for branch 'main':
# Commit ID: 391f5f510859b4ceea9f2f40e7cc605805f6d485
# Author: thc225 <thc225@lehigh.edu>
# Date: 2024-09-06T00:19:35.000-04:00
# Message: completed Question 6/Quiz 1
#
# ----------------------------------------
# Commit ID: fb43554adc576f9e137e24c30ccc51d05df066cc
# Author: thc225 <thc225@lehigh.edu>
# Date: 2024-09-06T00:13:40.000-04:00
# Message: completed Question 5
#
# ----------------------------------------
# Commit ID: 37bd8aec9a042fd57ca7b85774bb672a4a6ec147
# Author: thc225 <thc225@lehigh.edu>
# Date: 2024-09-05T23:42:29.000-04:00
# Message: completed Question 4
#
# ----------------------------------------
# Commit ID: 987aef3de00b48674bf404f354a17e6e515bba71
# Author: thc225 <thc225@lehigh.edu>
# Date: 2024-09-05T23:34:36.000-04:00
# Message: completed Question 3
#
# ----------------------------------------
# Commit ID: f60f4ae9739316e14a8ded9113a2e5437b1c6800
# Author: thc225 <thc225@lehigh.edu>
# Date: 2024-09-05T23:17:12.000-04:00
# Message: completed Question 2
#
# ----------------------------------------
# Commit ID: 841531bd2ec8b4724f4fd275098ead669afaefe3
# Author: thc225 <thc225@lehigh.edu>
# Date: 2024-09-05T23:06:37.000-04:00
# Message: completed Question 1
#
# ----------------------------------------
# Commit ID: 49c1136e79ec887b17d1ca8a468619c358e6653a
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:14:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: a60933a085c31dce3488d0f2c5badbc480017b08
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:47.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: c6b5d4c95af2b5f51090f6bf8f8bd60ed59f5428
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:04.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: e8d19a850098ce2d0eb486c38ee7b79c1b93eb2e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:12:30.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b637fa4f0606d08296b456eae9faf504e2465b3f
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:53.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 36751af0d496b12a77832b8d5218c538314de147
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:26.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b6e5cb3df02e086cb2f978e883188da754033c68
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-06T16:18:43.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 62b1ed122e385497e7ce37de7a03e0d626a00e76
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-05T14:16:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 3e4cd7d66509feda1cfbb998e2de0499696fd0b0
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:30:56.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: ac07498750689ea3e4ef31be6cb84eb62e5d494e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:22:36.000+00:00
# Message: Initial commit
# ----------------------------------------
#
# Commits per author on branch 'main':
# thc225: 6 commit(s)
# Corey Montella: 10 commit(s)
#
# Commit frequency on branch 'main':
# 2023-02-09: 2 commit(s)
# 2023-09-05: 1 commit(s)
# 2023-09-06: 1 commit(s)
# 2024-01-31: 2 commit(s)
# 2024-09-04: 4 commit(s)
# 2024-09-05: 4 commit(s)
# 2024-09-06: 2 commit(s)
#
# All required files are present.
#
# No merge requests found.
#
# No CI/CD pipelines found for branch 'main'.
# 0
# Successfully authenticated with GitLab.
# Accessed project: Quiz 1
# Available branches:
#   - main
#
# Default branch detected: main
#
# Contents of the repository 'Quiz 1':
#   📄 README.md
# Failed to retrieve the file 'tests/lex.rs'. Make sure it exists.
#
# Number of tests in 'tests/lex.rs': 0
# No CI/CD pipelines found for branch 'main'.
# Total number of commits on branch 'main': 11
#
# Commit Details for branch 'main':
# Commit ID: 0dad4098e9e4b8bcf6f9b650ed81246dd827cdac
# Author: Chambers, Earl L. <elc225@lehigh.edu>
# Date: 2024-09-10T17:07:01.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 49c1136e79ec887b17d1ca8a468619c358e6653a
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:14:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: a60933a085c31dce3488d0f2c5badbc480017b08
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:47.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: c6b5d4c95af2b5f51090f6bf8f8bd60ed59f5428
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:04.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: e8d19a850098ce2d0eb486c38ee7b79c1b93eb2e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:12:30.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b637fa4f0606d08296b456eae9faf504e2465b3f
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:53.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 36751af0d496b12a77832b8d5218c538314de147
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:26.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b6e5cb3df02e086cb2f978e883188da754033c68
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-06T16:18:43.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 62b1ed122e385497e7ce37de7a03e0d626a00e76
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-05T14:16:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 3e4cd7d66509feda1cfbb998e2de0499696fd0b0
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:30:56.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: ac07498750689ea3e4ef31be6cb84eb62e5d494e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:22:36.000+00:00
# Message: Initial commit
# ----------------------------------------
#
# Commits per author on branch 'main':
# Chambers, Earl L.: 1 commit(s)
# Corey Montella: 10 commit(s)
#
# Commit frequency on branch 'main':
# 2023-02-09: 2 commit(s)
# 2023-09-05: 1 commit(s)
# 2023-09-06: 1 commit(s)
# 2024-01-31: 2 commit(s)
# 2024-09-04: 4 commit(s)
# 2024-09-10: 1 commit(s)
#
# All required files are present.
#
# No merge requests found.
#
# No CI/CD pipelines found for branch 'main'.
# 0
# Successfully authenticated with GitLab.
# Accessed project: Quiz 1
# Available branches:
#   - main
#
# Default branch detected: main
#
# Contents of the repository 'Quiz 1':
#   📄 README.md
# Failed to retrieve the file 'tests/lex.rs'. Make sure it exists.
#
# Number of tests in 'tests/lex.rs': 0
# No CI/CD pipelines found for branch 'main'.
# Total number of commits on branch 'main': 16
#
# Commit Details for branch 'main':
# Commit ID: 6f864097bf868544ee96cc0fe0a2d62d009ea780
# Author: Rico Chen <yic625@lehigh.edu>
# Date: 2024-09-07T21:18:07.000-04:00
# Message: format still look not good i giveup im not very familar with markdown file im so sorry
#
# ----------------------------------------
# Commit ID: 20cc66a6d894047f76cad788b4cf5154e34bc91d
# Author: Rico Chen <yic625@lehigh.edu>
# Date: 2024-09-07T21:17:30.000-04:00
# Message: modify q3 q4 format looks wired on gitlab side
#
# ----------------------------------------
# Commit ID: b6aa693b1bdf21e20ea09f35dd89972c93baa77c
# Author: Rico Chen <yic625@lehigh.edu>
# Date: 2024-09-07T21:16:38.000-04:00
# Message: modify q2
#
# ----------------------------------------
# Commit ID: c653c43a525b6cd6091f10494b8f23cad2d444e5
# Author: Rico Chen <yic625@lehigh.edu>
# Date: 2024-09-07T21:16:09.000-04:00
# Message: modify q1
#
# ----------------------------------------
# Commit ID: 7f6d400b9730587767b45bbcb16ce7572db5fbcd
# Author: Rico Chen <yic625@lehigh.edu>
# Date: 2024-09-07T21:15:13.000-04:00
# Message: modify q6
#
# ----------------------------------------
# Commit ID: 77bfca9cef4690c4f53186a885912bdd27352df9
# Author: Rico Chen <yic625@lehigh.edu>
# Date: 2024-09-07T21:13:02.000-04:00
# Message: submission
#
# ----------------------------------------
# Commit ID: 49c1136e79ec887b17d1ca8a468619c358e6653a
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:14:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: a60933a085c31dce3488d0f2c5badbc480017b08
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:47.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: c6b5d4c95af2b5f51090f6bf8f8bd60ed59f5428
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:04.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: e8d19a850098ce2d0eb486c38ee7b79c1b93eb2e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:12:30.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b637fa4f0606d08296b456eae9faf504e2465b3f
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:53.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 36751af0d496b12a77832b8d5218c538314de147
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:26.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b6e5cb3df02e086cb2f978e883188da754033c68
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-06T16:18:43.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 62b1ed122e385497e7ce37de7a03e0d626a00e76
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-05T14:16:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 3e4cd7d66509feda1cfbb998e2de0499696fd0b0
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:30:56.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: ac07498750689ea3e4ef31be6cb84eb62e5d494e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:22:36.000+00:00
# Message: Initial commit
# ----------------------------------------
#
# Commits per author on branch 'main':
# Rico Chen: 6 commit(s)
# Corey Montella: 10 commit(s)
#
# Commit frequency on branch 'main':
# 2023-02-09: 2 commit(s)
# 2023-09-05: 1 commit(s)
# 2023-09-06: 1 commit(s)
# 2024-01-31: 2 commit(s)
# 2024-09-04: 4 commit(s)
# 2024-09-07: 6 commit(s)
#
# All required files are present.
#
# No merge requests found.
#
# No CI/CD pipelines found for branch 'main'.
# 0
# Successfully authenticated with GitLab.
# Accessed project: Quiz 1
# Available branches:
#   - main
#
# Default branch detected: main
#
# Contents of the repository 'Quiz 1':
#   📄 README.md
# Failed to retrieve the file 'tests/lex.rs'. Make sure it exists.
#
# Number of tests in 'tests/lex.rs': 0
# No CI/CD pipelines found for branch 'main'.
# Total number of commits on branch 'main': 16
#
# Commit Details for branch 'main':
# Commit ID: 6b4bd1615edbf0e0dffb4165b89d0a3baacf4961
# Author: aac325 <aac325@lehigh.edu>
# Date: 2024-09-11T21:22:00.000-04:00
# Message: Finished last question
#
# ----------------------------------------
# Commit ID: bb1c5a34e56ba06ecbddfc045ef021686bf318ca
# Author: aac325 <aac325@lehigh.edu>
# Date: 2024-09-11T21:19:38.000-04:00
# Message: Finished question 5.
#
# ----------------------------------------
# Commit ID: e11897dd6105405df0659a327b866182a78d8b07
# Author: aac325 <aac325@lehigh.edu>
# Date: 2024-09-11T21:12:50.000-04:00
# Message: Finished question 4
#
# ----------------------------------------
# Commit ID: 2e2fc83ccdb5054e5e78b231151002cc115c811b
# Author: aac325 <aac325@lehigh.edu>
# Date: 2024-09-11T21:01:24.000-04:00
# Message: Finished question 3
#
# ----------------------------------------
# Commit ID: 5fdbf788dd2ad04c255fa51ef4a99650096f45ec
# Author: aac325 <aac325@lehigh.edu>
# Date: 2024-09-11T20:44:57.000-04:00
# Message: Finished question 2
#
# ----------------------------------------
# Commit ID: f309b2b06cd1e3cb31e12eadb8e1c9561d66562a
# Author: aac325 <aac325@lehigh.edu>
# Date: 2024-09-11T20:40:37.000-04:00
# Message: Finished question 1
#
# ----------------------------------------
# Commit ID: 49c1136e79ec887b17d1ca8a468619c358e6653a
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:14:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: a60933a085c31dce3488d0f2c5badbc480017b08
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:47.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: c6b5d4c95af2b5f51090f6bf8f8bd60ed59f5428
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:04.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: e8d19a850098ce2d0eb486c38ee7b79c1b93eb2e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:12:30.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b637fa4f0606d08296b456eae9faf504e2465b3f
# ...
# ----------------------------------------
# Commit ID: b6e5cb3df02e086cb2f978e883188da754033c68
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-06T16:18:43.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 62b1ed122e385497e7ce37de7a03e0d626a00e76
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-05T14:16:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 3e4cd7d66509feda1cfbb998e2de0499696fd0b0
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:30:56.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: ac07498750689ea3e4ef31be6cb84eb62e5d494e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:22:36.000+00:00
# Message: Initial commit
# ----------------------------------------
#
# Commits per author on branch 'main':
# Kaylee Van Eps: 2 commit(s)
# Corey Montella: 10 commit(s)
#
# Commit frequency on branch 'main':
# 2023-02-09: 2 commit(s)
# 2023-09-05: 1 commit(s)
# 2023-09-06: 1 commit(s)
# 2024-01-31: 2 commit(s)
# 2024-09-04: 6 commit(s)
#
# All required files are present.
#
# No merge requests found.
#
# No CI/CD pipelines found for branch 'main'.
# 0
# Successfully authenticated with GitLab.
# Accessed project: Quiz 1
# Available branches:
#   - main
#
# Default branch detected: main
#
# Contents of the repository 'Quiz 1':
#   📄 README.md
# Failed to retrieve the file 'tests/lex.rs'. Make sure it exists.
#
# Number of tests in 'tests/lex.rs': 0
# No CI/CD pipelines found for branch 'main'.
# Total number of commits on branch 'main': 16
#
# Commit Details for branch 'main':
# Commit ID: a2bdb34e0e31549fe01d61a1d65a2a54523025df
# Author: Villeta, Vicky <viv226@lehigh.edu>
# Date: 2024-09-06T03:55:06.000+00:00
# Message: Question 6 done
# ----------------------------------------
# Commit ID: 7f107089dedfbc01f73d1a14645ea4c085001f82
# Author: Villeta, Vicky <viv226@lehigh.edu>
# Date: 2024-09-06T03:36:18.000+00:00
# Message: Question 5 done
# ----------------------------------------
# Commit ID: e0e0b46f62674742cd4a70386389f4f93173cd64
# Author: Villeta, Vicky <viv226@lehigh.edu>
# Date: 2024-09-06T03:29:22.000+00:00
# Message: Question 4 done
# ----------------------------------------
# Commit ID: 660f60f1276167006c4b407734d60e2f5c920677
# Author: Villeta, Vicky <viv226@lehigh.edu>
# Date: 2024-09-06T03:08:05.000+00:00
# Message: Question 3 done
# ----------------------------------------
# Commit ID: a5b293ceb89d22c4fc9da4ec818534d23bec3e55
# Author: Villeta, Vicky <viv226@lehigh.edu>
# Date: 2024-09-06T02:58:03.000+00:00
# Message: Question 2 done
# ----------------------------------------
# Commit ID: f801048a53d6c54df48fc2147ab7444ff5879ef7
# Author: Villeta, Vicky <viv226@lehigh.edu>
# Date: 2024-09-06T02:50:33.000+00:00
# Message: Question 1 done
# ----------------------------------------
# Commit ID: 49c1136e79ec887b17d1ca8a468619c358e6653a
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:14:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: a60933a085c31dce3488d0f2c5badbc480017b08
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:47.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: c6b5d4c95af2b5f51090f6bf8f8bd60ed59f5428
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:04.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: e8d19a850098ce2d0eb486c38ee7b79c1b93eb2e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:12:30.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b637fa4f0606d08296b456eae9faf504e2465b3f
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:53.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 36751af0d496b12a77832b8d5218c538314de147
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:26.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b6e5cb3df02e086cb2f978e883188da754033c68
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-06T16:18:43.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 62b1ed122e385497e7ce37de7a03e0d626a00e76
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-05T14:16:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 3e4cd7d66509feda1cfbb998e2de0499696fd0b0
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:30:56.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: ac07498750689ea3e4ef31be6cb84eb62e5d494e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:22:36.000+00:00
# Message: Initial commit
# ----------------------------------------
#
# Commits per author on branch 'main':
# Villeta, Vicky: 6 commit(s)
# Corey Montella: 10 commit(s)
#
# Commit frequency on branch 'main':
# 2023-02-09: 2 commit(s)
# 2023-09-05: 1 commit(s)
# 2023-09-06: 1 commit(s)
# 2024-01-31: 2 commit(s)
# 2024-09-04: 4 commit(s)
# 2024-09-06: 6 commit(s)
#
# All required files are present.
#
# No merge requests found.
#
# No CI/CD pipelines found for branch 'main'.
# 0
# Successfully authenticated with GitLab.
# Accessed project: Quiz 1
# Available branches:
#   - main
#
# Default branch detected: main
#
# Contents of the repository 'Quiz 1':
#   📄 README.md
# Failed to retrieve the file 'tests/lex.rs'. Make sure it exists.
#
# Number of tests in 'tests/lex.rs': 0
# No CI/CD pipelines found for branch 'main'.
# Total number of commits on branch 'main': 13
#
# Commit Details for branch 'main':
# Commit ID: 602daa7021ce70ac1356775ea7d059a0ec11c953
# Author: Nga Vu <134727438+zlnga1001@users.noreply.github.com>
# Date: 2024-09-06T22:30:01.000-04:00
# Message: modified
#
# ----------------------------------------
# Commit ID: 5502b5d5b51866bb2a18958f9cba0b03d3e9bdac
# Author: Nga Vu <134727438+zlnga1001@users.noreply.github.com>
# Date: 2024-09-06T22:29:38.000-04:00
# Message: modified
#
# ----------------------------------------
# Commit ID: cf3b2b5fda2b1443cb60ca6d36be91cdbb284c95
# Author: Nga Vu <134727438+zlnga1001@users.noreply.github.com>
# Date: 2024-09-06T22:28:19.000-04:00
# Message: fixed
#
# ----------------------------------------
# Commit ID: 49c1136e79ec887b17d1ca8a468619c358e6653a
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:14:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: a60933a085c31dce3488d0f2c5badbc480017b08
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:47.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: c6b5d4c95af2b5f51090f6bf8f8bd60ed59f5428
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:04.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: e8d19a850098ce2d0eb486c38ee7b79c1b93eb2e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:12:30.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b637fa4f0606d08296b456eae9faf504e2465b3f
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:53.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 36751af0d496b12a77832b8d5218c538314de147
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:26.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b6e5cb3df02e086cb2f978e883188da754033c68
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-06T16:18:43.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 62b1ed122e385497e7ce37de7a03e0d626a00e76
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-05T14:16:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 3e4cd7d66509feda1cfbb998e2de0499696fd0b0
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:30:56.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: ac07498750689ea3e4ef31be6cb84eb62e5d494e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:22:36.000+00:00
# Message: Initial commit
# ----------------------------------------
#
# Commits per author on branch 'main':
# Nga Vu: 3 commit(s)
# Corey Montella: 10 commit(s)
#
# Commit frequency on branch 'main':
# 2023-02-09: 2 commit(s)
# 2023-09-05: 1 commit(s)
# 2023-09-06: 1 commit(s)
# 2024-01-31: 2 commit(s)
# 2024-09-04: 4 commit(s)
# 2024-09-06: 3 commit(s)
#
# All required files are present.
#
# No merge requests found.
#
# No CI/CD pipelines found for branch 'main'.
# 0
# Successfully authenticated with GitLab.
# Accessed project: Quiz 1
# Available branches:
#   - main
#
# Default branch detected: main
#
# Contents of the repository 'Quiz 1':
#   📄 README.md
# Failed to retrieve the file 'tests/lex.rs'. Make sure it exists.
#
# Number of tests in 'tests/lex.rs': 0
# No CI/CD pipelines found for branch 'main'.
# Total number of commits on branch 'main': 13
#
# Commit Details for branch 'main':
# Commit ID: 006a2476496d7cc70bb6ed45e87af097d4b6299a
# Author: Sam Wiley <sew225@lehigh.edu>
# Date: 2024-09-09T21:10:54.000-04:00
# Message: redid question 5 and finished question 6
#
# ----------------------------------------
# Commit ID: ef9ed4913b29a1246db2abc7e623cef1bbfd79fe
# Author: Sam Wiley <sew225@lehigh.edu>
# Date: 2024-09-09T21:06:22.000-04:00
# Message: question 4 + 5
#
# ----------------------------------------
# Commit ID: d04af2b3e4ce681e806e64c55f8f6f7f2ddf0a86
# Author: Sam Wiley <sew225@lehigh.edu>
# Date: 2024-09-09T20:48:11.000-04:00
# Message: forgot to commit each question before this but here is questions 1-3
#
# ----------------------------------------
# Commit ID: 49c1136e79ec887b17d1ca8a468619c358e6653a
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:14:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: a60933a085c31dce3488d0f2c5badbc480017b08
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:47.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: c6b5d4c95af2b5f51090f6bf8f8bd60ed59f5428
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:04.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: e8d19a850098ce2d0eb486c38ee7b79c1b93eb2e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:12:30.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b637fa4f0606d08296b456eae9faf504e2465b3f
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:53.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 36751af0d496b12a77832b8d5218c538314de147
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:26.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b6e5cb3df02e086cb2f978e883188da754033c68
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-06T16:18:43.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 62b1ed122e385497e7ce37de7a03e0d626a00e76
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-05T14:16:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 3e4cd7d66509feda1cfbb998e2de0499696fd0b0
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:30:56.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: ac07498750689ea3e4ef31be6cb84eb62e5d494e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:22:36.000+00:00
# Message: Initial commit
# ----------------------------------------
#
# Commits per author on branch 'main':
# Sam Wiley: 3 commit(s)
# Corey Montella: 10 commit(s)
#
# Commit frequency on branch 'main':
# 2023-02-09: 2 commit(s)
# 2023-09-05: 1 commit(s)
# 2023-09-06: 1 commit(s)
# 2024-01-31: 2 commit(s)
# 2024-09-04: 4 commit(s)
# 2024-09-09: 3 commit(s)
#
# All required files are present.
#
# No merge requests found.
#
# No CI/CD pipelines found for branch 'main'.
# 0
# Successfully authenticated with GitLab.
# Accessed project: Quiz 1
# Available branches:
#   - main
#
# Default branch detected: main
#
# Contents of the repository 'Quiz 1':
#   📄 README.md
# Failed to retrieve the file 'tests/lex.rs'. Make sure it exists.
#
# Number of tests in 'tests/lex.rs': 0
# No CI/CD pipelines found for branch 'main'.
# Total number of commits on branch 'main': 16
#
# Commit Details for branch 'main':
# Commit ID: 346523cb597d5c1da628b1df2ce95e52547f2e26
# Author: Jason Ye <jasonye0104@gmail.com>
# Date: 2024-09-09T19:51:36.000-04:00
# Message: Answered Q6
#
# ----------------------------------------
# Commit ID: 13c40c0d8c7238ea9120e00624049618af25c603
# Author: Jason Ye <jasonye0104@gmail.com>
# Date: 2024-09-09T19:49:56.000-04:00
# Message: Answered Q5
#
# ----------------------------------------
# Commit ID: f3e7bcf867f9b9d076039534b4f90ccd529d73f1
# Author: Jason Ye <jasonye0104@gmail.com>
# Date: 2024-09-09T19:49:44.000-04:00
# Message: Answered Q5
#
# ----------------------------------------
# Commit ID: 5f622b932d2c48303ce2ba809dbeb6a33222ef5e
# Author: Jason Ye <jasonye0104@gmail.com>
# Date: 2024-09-09T19:42:37.000-04:00
# Message: Q3 Answered
#
# ----------------------------------------
# Commit ID: b52ce3b65e5b2a5d28027eeb98125b25ede04a97
# Author: Jason Ye <jasonye0104@gmail.com>
# Date: 2024-09-09T19:40:06.000-04:00
# Message: Q2 Answered
#
# ----------------------------------------
# Commit ID: 0a7402b6f0ca43c5fb72260aaa5d02774a43b04d
# Author: Jason Ye <jasonye0104@gmail.com>
# Date: 2024-09-09T19:36:50.000-04:00
# Message: Q1 Answered
#
# ----------------------------------------
# Commit ID: 49c1136e79ec887b17d1ca8a468619c358e6653a
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:14:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: a60933a085c31dce3488d0f2c5badbc480017b08
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:47.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: c6b5d4c95af2b5f51090f6bf8f8bd60ed59f5428
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:13:04.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: e8d19a850098ce2d0eb486c38ee7b79c1b93eb2e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:12:30.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b637fa4f0606d08296b456eae9faf504e2465b3f
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:53.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 36751af0d496b12a77832b8d5218c538314de147
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-01-31T15:55:26.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: b6e5cb3df02e086cb2f978e883188da754033c68
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-06T16:18:43.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 62b1ed122e385497e7ce37de7a03e0d626a00e76
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-09-05T14:16:12.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 3e4cd7d66509feda1cfbb998e2de0499696fd0b0
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:30:56.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: ac07498750689ea3e4ef31be6cb84eb62e5d494e
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2023-02-09T03:22:36.000+00:00
# Message: Initial commit
# ----------------------------------------
#
# Commits per author on branch 'main':
# Jason Ye: 6 commit(s)
# Corey Montella: 10 commit(s)
#
# Commit frequency on branch 'main':
# 2023-02-09: 2 commit(s)
# 2023-09-05: 1 commit(s)
# 2023-09-06: 1 commit(s)
# 2024-01-31: 2 commit(s)
# 2024-09-04: 4 commit(s)
# 2024-09-09: 6 commit(s)
#
# All required files are present.
#
# No merge requests found.
#
# No CI/CD pipelines found for branch 'main'.
# 0
# Successfully authenticated with GitLab.
# Failed to retrieve the project. Please check the repository URL.
# Repo for nay225 is not good!
# 256

# %%
import os
import subprocess

# Path to the base directory where all the student folders are located
base_dir = os.path.abspath("./repo/homework-1")  # Using absolute path to avoid relative path issues

result_dir = os.path.join(base_dir, "results.txt")

if not os.path.exists(result_dir):
    with open(result_dir, "w") as f:
        f.write("")  # Create the file if it doesn't exist

# Function to run cargo test and check results
def run_cargo_test_in_folder(folder_path):
    try:
        # Change to the homework-1 directory
        os.chdir(folder_path)

        # Run the `cargo test` command and capture the output
        result = subprocess.run(['cargo', 'test'], stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

        # Check if cargo test executed successfully
        if result.returncode == 0:
            output = result.stdout

            # Find the line containing the test result summary
            for line in output.splitlines():
                if "test result:" in line:
                    # Parse the result to extract passed and total tests
                    passed_tests = int(line.split("passed;")[0].split()[-1])
                    failed_tests = int(line.split("failed;")[0].split()[-1])
                    
                    total_tests = passed_tests + failed_tests
                    
                    print(f"{folder_path}: {passed_tests}/{total_tests} tests passed.")
                    with open(result_dir, "a") as f:
                        f.write(f"{folder_path}: {passed_tests}/{total_tests} tests passed.\n")
                    return True
            
            print(f"{folder_path}: No test results found.")
        else:
            print(f"{folder_path}: cargo test failed to execute.")
    except Exception as e:
        print(f"Error in {folder_path}: {e}")
    finally:
        # Return to the original directory
        os.chdir(base_dir)

# Loop through each student's directory and run tests
def main():
    # Get the list of student directories
    student_folders = peoples

    # write something here to record if all people are tested or not
    is_test_array = [False] * len(student_folders)
    

    # Iterate through each student folder
    for student_folder in student_folders:
        # Construct the path to the homework-1 directory, normalize it for cross-platform compatibility
        hw1_folder = os.path.normpath(os.path.join(base_dir, student_folder + '-cse262', 'homework-1'))

        # Check if homework-1 directory exists
        if os.path.exists(hw1_folder):
            is_test_successful = run_cargo_test_in_folder(hw1_folder)
            # if the cargo test is successful, set the is_test_array to True
            if is_test_successful:
                is_test_array[student_folders.index(student_folder)] = True
        else:
            print(f"{student_folder} does not have a homework-1 folder.")

if __name__ == "__main__":
    main()
# Out:
# /home/soz223/cse262grading/repo/homework-1/ala226-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/ala226-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/sea325-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/sea325-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/rvb226-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/rvb226-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/cjb325-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/cjb325-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/ccb226-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/ccb226-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/job426-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/job426-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/jbb225-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/jbb225-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/beb727-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/beb727-cse262/quiz-1` or any parent directory
#
# gcb325 does not have a quiz folder.
# /home/soz223/cse262grading/repo/homework-1/kbc225-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/kbc225-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/thc225-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/thc225-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/elc225-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/elc225-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/yic625-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/yic625-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/aac325-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/aac325-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/djc226-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/djc226-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/clc226-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/clc226-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/dac225-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/dac225-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/thd226-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/thd226-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/jad626-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/jad626-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/mfd223-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/mfd223-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/lgd226-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/lgd226-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/zaf326-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/zaf326-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/mjf326-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/mjf326-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/bwf225-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/bwf225-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/jwf226-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/jwf226-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/asf327-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/asf327-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/aif226-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/aif226-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/ckf225-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/ckf225-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/mjg526-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/mjg526-cse262/quiz-1` or any parent directory
#
# mpg226 does not have a quiz folder.
# /home/soz223/cse262grading/repo/homework-1/avh226-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/avh226-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/adh226-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/adh226-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/beh427-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/beh427-cse262/quiz-1` or any parent directory
#
# /home/soz223/cse262grading/repo/homework-1/hph225-cse262/quiz-1: cargo test failed to execute.
# error: could not find `Cargo.toml` in `/home/soz223/cse262grading/repo/homework-1/hph225-cse262/quiz-1` or any parent directory
#
# yih226 does not have a quiz folder.
# dai226 does not have a quiz folder.
# tti225 does not have a quiz folder.
# mni226 does not have a quiz folder.
# cbj225 does not have a quiz folder.
# ayj325 does not have a quiz folder.
# wtj226 does not have a quiz folder.
# krj225 does not have a quiz folder.
# svk326 does not have a quiz folder.
# sak625 does not have a quiz folder.
# kck225 does not have a quiz folder.
# tal225 does not have a quiz folder.
# rol226 does not have a quiz folder.
# ktl225 does not have a quiz folder.
# awl225 does not have a quiz folder.
# pjl224 does not have a quiz folder.
# anl226 does not have a quiz folder.
# ttl225 does not have a quiz folder.
# efl226 does not have a quiz folder.
# tel225 does not have a quiz folder.
# pam226 does not have a quiz folder.
# sjm225 does not have a quiz folder.
# cam723 does not have a quiz folder.
# dhm327 does not have a quiz folder.
# lom225 does not have a quiz folder.
# mtm225 does not have a quiz folder.
# dpm227 does not have a quiz folder.
# svm227 does not have a quiz folder.
# sin225 does not have a quiz folder.
# asn226 does not have a quiz folder.
# han225 does not have a quiz folder.
# aan426 does not have a quiz folder.
# nep225 does not have a quiz folder.
# top226 does not have a quiz folder.
# ecp327 does not have a quiz folder.
# lup225 does not have a quiz folder.
# lar326 does not have a quiz folder.
# ccr225 does not have a quiz folder.
# mis225 does not have a quiz folder.
# mas326 does not have a quiz folder.
# jos226 does not have a quiz folder.
# cds225 does not have a quiz folder.
# besa26 does not have a quiz folder.
# ersa26 does not have a quiz folder.
# jds327 does not have a quiz folder.
# bes227 does not have a quiz folder.
# res422 does not have a quiz folder.
# dms425 does not have a quiz folder.
# ait226 does not have a quiz folder.
# apt226 does not have a quiz folder.
# kav225 does not have a quiz folder.
# viv226 does not have a quiz folder.
# nlv226 does not have a quiz folder.
# sew225 does not have a quiz folder.
# jiy225 does not have a quiz folder.
# nay225 does not have a quiz folder.
