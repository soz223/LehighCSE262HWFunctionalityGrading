# %%
import os
with open('participants.txt') as f:
    # peoples = f.readlines().remove('\n')
    peoples = f.read().splitlines()

# Loop through each email and extract the username part (before '@lehigh.edu')
for people in peoples:
    
    # Construct the GitLab repo URL using the email username
    repo_url = f"http://gitlab.cse.lehigh.edu/{people}-cse262/homework-3"
    
    # Call the Python script to check the repo
    # You would use os.system() or subprocess to execute the shell command

    # if exception occurs, print the error message
    try:
        error = os.system(f"python check_repo.py {repo_url}")
    except Exception as e:
        error = 1
        print(f"Error checking repo for {people}: {e}")

# Path to the base directory where all the student folders are located
base_dir = os.path.abspath("./repo/homework-3")  # Using absolute path to avoid relative path issues

result_dir = os.path.join(base_dir, "results.txt")

if not os.path.exists(result_dir):
    with open(result_dir, "w") as f:
        f.write("")  # Create the file if it doesn't exist
# Out:
# Successfully authenticated with GitLab.
# Accessed project: Homework 2
# Available branches:
#   - main
#
# Default branch detected: main
#
# Contents of the repository 'Homework 2':
#   📁 src/
#   📁 tests/
#   📄 .gitignore
#   📄 .gitlab-ci.yml
#   📄 Cargo.lock
#   📄 Cargo.toml
#   📄 README.md
# Total number of commits on branch 'main': 14
#
# Commit Details for branch 'main':
# Commit ID: 3e28001b3f8485bb56898339176970f94deb6d1d
# Author: ssh-rsa ... soz223@lehigh.edu <soz223@ceres.cse.lehigh.edu>
# Date: 2024-09-25T23:16:13.000-04:00
# Message: test commit
#
# ----------------------------------------
# Commit ID: 4841f4a466bbb30c387f806602b2c27fd37eeed3
# Author: 3072925483hsl@gmail.com <3072925483hsl@gmail.com>
# Date: 2024-09-08T21:57:57.000-04:00
# Message: pass test 12. some erroreous bugs in test. also chagnes
#
# ----------------------------------------
# Commit ID: f02353bec0acd205988f2217cb4c294becd9af5a
# Author: 3072925483hsl@gmail.com <3072925483hsl@gmail.com>
# Date: 2024-09-08T20:23:46.000-04:00
# Message: add keywords
#
# ----------------------------------------
# Commit ID: e9dc1d61482319f5049610952c9246b5a49353e5
# Author: 3072925483hsl@gmail.com <3072925483hsl@gmail.com>
# Date: 2024-09-08T20:02:41.000-04:00
# Message: consider about + - = " ; white space
#
# ----------------------------------------
# Commit ID: 000565dfbcf782e5e6a1fec44a16ebf0cafdd056
# Author: 3072925483hsl@gmail.com <3072925483hsl@gmail.com>
# Date: 2024-09-08T16:46:32.000-04:00
# Message: add string, test 8
#
# ----------------------------------------
# Commit ID: 036841011233e5cba93d52f082dab32bc8d42dd5
# Author: 3072925483hsl@gmail.com <3072925483hsl@gmail.com>
# Date: 2024-09-08T16:34:50.000-04:00
# Message: pass test 6 and 8
#
# ----------------------------------------
# Commit ID: 5b7cde8aeb6c4d75e94106115507c2d7b5f603ef
# Author: 3072925483hsl@gmail.com <3072925483hsl@gmail.com>
# Date: 2024-09-08T15:55:20.000-04:00
# Message: pass test 4 and 5
#
# ----------------------------------------
# Commit ID: 4c4883d9f71d5e79cc967c374b5a7f78f18461d8
# Author: 3072925483hsl@gmail.com <3072925483hsl@gmail.com>
# Date: 2024-09-08T15:35:34.000-04:00
# Message: pass for test 2 and 3
#
# ----------------------------------------
# Commit ID: a0426070dc71d779764eeef8de4b861af9ef3d08
# Author: 3072925483hsl@gmail.com <3072925483hsl@gmail.com>
# Date: 2024-09-08T15:21:49.000-04:00
# Message: temporarily comment some for tests
#
# ----------------------------------------
# Commit ID: 0e79c7be45f5ca8de67a1cd7b5f882c178338121
# Author: 3072925483hsl@gmail.com <3072925483hsl@gmail.com>
# Date: 2024-09-08T15:21:17.000-04:00
# Message: make struct Token key pub so can pass the test
#
# ----------------------------------------
# Commit ID: a258f52fd08d7f3273ac454bf94fef8b7550d4a7
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T15:01:03.000+00:00
# Message: Update README.md
# ----------------------------------------
# Commit ID: 90051bac3c3fbaeac438df1234bf59fbd514cdd3
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T13:09:51.000+00:00
# Message: Initial Commit
# ----------------------------------------
# Commit ID: a7950fb3231a3295f8e436145e026cb687be0f27
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T12:26:33.000+00:00
# Message: Delete README.md
# ----------------------------------------
# Commit ID: d08abfae5e7c11bfaf36dbdf6bae8ed75f12cfe9
# Author: Corey Montella <cim310@lehigh.edu>
# Date: 2024-09-04T12:26:20.000+00:00
# Message: Initial commit
# ----------------------------------------
# home work number: 2
# commit count: 14
#
# Commits per author on branch 'main':
# ssh-rsa ... soz223@lehigh.edu: 1 commit(s)
# 3072925483hsl@gmail.com: 9 commit(s)
# Corey Montella: 4 commit(s)
#
# Commit frequency on branch 'main':
# 2024-09-04: 4 commit(s)
# 2024-09-08: 9 commit(s)
# 2024-09-25: 1 commit(s)
#
# All required files are present.
#
# No merge requests found.
# Commit date range after 2024-08-15: 2024-09-04 to 2024-09-25
#
# CI/CD Pipelines for branch 'main':
# ID: 10179, Status: success, Created At: 2024-09-26T03:16:22.232Z
# ID: 8908, Status: success, Created At: 2024-09-09T01:58:04.531Z
# ID: 8907, Status: failed, Created At: 2024-09-09T00:23:51.948Z
# ID: 8906, Status: success, Created At: 2024-09-09T00:02:47.299Z
# ID: 8895, Status: success, Created At: 2024-09-08T20:46:39.743Z
# ID: 8893, Status: success, Created At: 2024-09-08T20:35:10.691Z
# ID: 8892, Status: success, Created At: 2024-09-08T19:55:27.544Z
# ID: 8891, Status: success, Created At: 2024-09-08T19:36:06.203Z
# ID: 8890, Status: success, Created At: 2024-09-08T19:21:54.482Z
#
#
#
#
# --------------------------------------------------
# Latest CI/CD pipeline passed
# --------------------------------------------------
# Job ID: 11848, Name: test:cargo, Status: success
# Test Analysis for Job ID 11848:
#   Total tests run: 24
#   Tests passed: 24
#   Tests failed: 0
